# %% [raw]
# pip list

# %% [raw]
# !pip install pandas

# %% [raw]
# !pip install xlrd

# %% [raw]
# !pip install openpyxl

# %% [markdown]
# # Чтение содержимого файлов

# %%
import pandas as pd

# %% [markdown]
# ## Интересы.xls

# %%
df = pd.read_excel('Interests_Calls_Volumes\Интересы.xls')
print(df.head(10))
# Out:
#                Дата                                               Тема  \
# 0  01.02.2023 07:26                Привлечение потенциального клиента.
# 1  01.02.2023 07:31                                Привлечение клиента
# 2  01.02.2023 07:45  Привлечение потенциального клиента ст. Подосин...
# 3  01.02.2023 08:22             Перевозка с Владимира - МСК, Ярославль
# 4  01.02.2023 08:37                 Привлечение потенциальных клиентов
# 5  01.02.2023 08:44                                Привлечение клиента
# 6  01.02.2023 09:16                                Привлечение клиента
# 7  01.02.2023 09:27                     ОБР_1120753 выгрузка Металлист
# 8  01.02.2023 09:51                 Привлечение потенциальных клиентов
# 9  01.02.2023 10:14                 Привлечение потенциальных клиентов
#
#           Сценарий          Состояние     ID Подразделение  Ожидаемая выручка  \
# 0  1.Продажа  ЦФТО  Завершен неудачно  17369    ЦПУ МУРАШИ                NaN
# 1  1.Продажа  ЦФТО  Завершен неудачно  13714    ЦПУ МУРАШИ                NaN
# 2  1.Продажа  ЦФТО  Завершен неудачно  14984    ЦПУ МУРАШИ                NaN
# 3  1.Продажа  ЦФТО  Завершен неудачно  14916  ЦПУ ВЛАДИМИР                NaN
# 4  1.Продажа  ЦФТО  Завершен неудачно  14257   ЦПУ ШАХУНЬЯ                NaN
# 5  1.Продажа  ЦФТО   Завершен успешно  20892    ЦПУ ИЖЕВСК            20000.0
# 6  1.Продажа  ЦФТО  Завершен неудачно  20567    ЦПУ ИЖЕВСК                NaN
# 7  1.Продажа  ЦФТО   Завершен успешно  14258   ЦПУ ШАХУНЬЯ                NaN
# 8  1.Продажа  ЦФТО  Завершен неудачно  14259   ЦПУ ШАХУНЬЯ                NaN
# 9  1.Продажа  ЦФТО   Завершен успешно  14408   ЦПУ ШАХУНЬЯ                NaN
#
#    Вероятность сделки, % Дата следующей активности Следующая активность  \
# 0                    NaN                       NaN                  NaN
# 1                    NaN                       NaN                  NaN
# 2                    NaN                       NaN                  NaN
# 3                    NaN                       NaN                  NaN
# 4                    NaN       13.03.2023 14:30:00               звонок
# 5                  100.0                       NaN                  NaN
# 6                    NaN                       NaN                  NaN
# 7                  100.0       02.02.2023 10:00:00               звонок
# 8                    NaN       28.02.2023 13:00:36               звонок
# 9                  100.0        27.03.2023 8:30:00               звонок
#
#   Канал первичного интереса        Номер  \
# 0       10. Холодный звонок  0001-022043
# 1       10. Холодный звонок  0001-022053
# 2       10. Холодный звонок  0001-022069
# 3                 Обращение  0001-022106
# 4       10. Холодный звонок  0001-022115
# 5       10. Холодный звонок  0001-022122
# 6       10. Холодный звонок  0001-022155
# 7                 Обращение  0001-022185
# 8       10. Холодный звонок  0001-022250
# 9       10. Холодный звонок  0001-022300
#
#   Ссылка (служебное поле для вывода на экран прочих реквизитов объекта)
# 0  Интерес "Привлечение потенциального клиента." ...
# 1        Интерес "Привлечение клиента" от 01.02.2023
# 2  Интерес "Привлечение потенциального клиента ст...
# 3  Интерес "Перевозка с Владимира - МСК, Ярославл...
# 4  Интерес "Привлечение потенциальных клиентов" о...
# 5  Интерес "Привлечение клиента" от 01.02.2023, 2...
# 6        Интерес "Привлечение клиента" от 01.02.2023
# 7  Интерес "ОБР_1120753 выгрузка Металлист" от 01...
# 8  Интерес "Привлечение потенциальных клиентов" о...
# 9  Интерес "Привлечение потенциальных клиентов" о...

# %% [markdown]
# ## Обращения.xls

# %%
df = pd.read_excel('Interests_Calls_Volumes\Обращения.xls')
print(df.head())
# Out:
#                Дата                                               Тема     ID  \
# 0  01.02.2022 15:52                       Заключение договоров: Другое  21082
# 1  01.02.2024 10:04  Оформление документов связанных с перевозкой г...   1923
# 2  01.02.2024 11:25                          Справочный запрос: Другое  11332
# 3  01.02.2024 11:28                          Справочный запрос: Другое  21155
# 4  01.02.2024 11:30  Справочный запрос: Регистрация официальных обр...  21283
#
#   Тип обращения        Номер  \
# 0     Обращение  0000-009659
# 1     Обращение  0001-025297
# 2     Обращение  0001-025498
# 3     Обращение  0001-025503
# 4     Обращение  0001-025506
#
#                                         Тема вопроса  \
# 0                               Заключение договоров
# 1  Оформление документов связанных с перевозкой г...
# 2                                  Справочный запрос
# 3                                  Справочный запрос
# 4                                  Справочный запрос
#
#                      Группа вопросов Количество доработок
# 0                             Другое                  NaN
# 1                       Заявка ГУ-12                  NaN
# 2                             Другое                  NaN
# 3                             Другое                  NaN
# 4  Регистрация официальных обращений                  NaN

# %% [markdown]
# ## Объёмы перевозок.xls

# %%
df = pd.read_excel('Interests_Calls_Volumes\Объёмы перевозок.xls')
print(df.head())
# Out:
#   Unnamed: 0             Unnamed: 1             Unnamed: 2 Unnamed: 3  \
# 0        NaN                    NaN                    NaN        NaN
# 1         ID  Субъект федерации отп  Субъект федерации наз  Код груза
# 2      21220      Рязанская область   Оренбургская область      39146
# 3        912      Кировская область    Саратовская область      32411
# 4        912      Кировская область        Приморский край      32411
#
#                Код валюты            рубли              рубли.1  \
# 0                   Месяц          2022/08              2022/08
# 1  Гр груза по опер.номен  Провозная плата  Объем перевозок(тн)
# 2                  МЕТИЗЫ                0                    0
# 3          ЧЕРНЫЕ МЕТАЛЛЫ                0                    0
# 4          ЧЕРНЫЕ МЕТАЛЛЫ           675705                  203
#
#            рубли.2              рубли.3          рубли.4  ...  \
# 0          2023/10              2023/10          2024/01  ...
# 1  Провозная плата  Объем перевозок(тн)  Провозная плата  ...
# 2                0                    0           140356  ...
# 3                0                    0                0  ...
# 4                0                    0                0  ...
#
#           рубли.54             рубли.55         рубли.56             рубли.57  \
# 0          2023/08              2023/08          2023/03              2023/03
# 1  Провозная плата  Объем перевозок(тн)  Провозная плата  Объем перевозок(тн)
# 2                0                    0                0                    0
# 3                0                    0                0                    0
# 4                0                    0                0                    0
#
#           рубли.58             рубли.59         рубли.60             рубли.61  \
# 0          2024/08              2024/08          2022/01              2022/01
# 1  Провозная плата  Объем перевозок(тн)  Провозная плата  Объем перевозок(тн)
# 2                0                    0                0                    0
# 3                0                    0                0                    0
# 4          4668608                 1155          1440050                  476
#
#           рубли.62             рубли.63
# 0          2023/07              2023/07
# 1  Провозная плата  Объем перевозок(тн)
# 2                0                    0
# 3                0                    0
# 4                0                    0
#
# [5 rows x 69 columns]

# %% [markdown]
# # Фильтрация
# ## https://habr.com/ru/articles/775548/

# %% [markdown]
# ## Объёмы перевозок.xls (Уникальных ID-956):

# %%
import pandas as pd

# %% [raw]
# # так называемая база (почти)
# input_file = r'Interests_Calls_Volumes\Объёмы перевозок.xls'
# output_file = r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx'
#
# data = pd.read_excel(input_file, header=2)
#
# filtered_data = data.groupby('ID').agg(
#     Провозная_плата_сумма=('Провозная плата', 'sum'),
#     Объем_перевозок_сумма=('Объем перевозок(тн)', 'sum')
# ).reset_index()
#
# filtered_data.to_excel(output_file, index=False)

# %%
input_file = r'Interests_Calls_Volumes\Объёмы перевозок.xls'
data = pd.read_excel(input_file, header=2)
data.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_5864d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5864d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_5864d_level0_col1" class="col_heading level0 col1" >Субъект федерации отп</th>
#       <th id="T_5864d_level0_col2" class="col_heading level0 col2" >Субъект федерации наз</th>
#       <th id="T_5864d_level0_col3" class="col_heading level0 col3" >Код груза</th>
#       <th id="T_5864d_level0_col4" class="col_heading level0 col4" >Гр груза по опер.номен</th>
#       <th id="T_5864d_level0_col5" class="col_heading level0 col5" >Провозная плата</th>
#       <th id="T_5864d_level0_col6" class="col_heading level0 col6" >Объем перевозок(тн)</th>
#       <th id="T_5864d_level0_col7" class="col_heading level0 col7" >Провозная плата.1</th>
#       <th id="T_5864d_level0_col8" class="col_heading level0 col8" >Объем перевозок(тн).1</th>
#       <th id="T_5864d_level0_col9" class="col_heading level0 col9" >Провозная плата.2</th>
#       <th id="T_5864d_level0_col10" class="col_heading level0 col10" >Объем перевозок(тн).2</th>
#       <th id="T_5864d_level0_col11" class="col_heading level0 col11" >Провозная плата.3</th>
#       <th id="T_5864d_level0_col12" class="col_heading level0 col12" >Объем перевозок(тн).3</th>
#       <th id="T_5864d_level0_col13" class="col_heading level0 col13" >Провозная плата.4</th>
#       <th id="T_5864d_level0_col14" class="col_heading level0 col14" >Объем перевозок(тн).4</th>
#       <th id="T_5864d_level0_col15" class="col_heading level0 col15" >Провозная плата.5</th>
#       <th id="T_5864d_level0_col16" class="col_heading level0 col16" >Объем перевозок(тн).5</th>
#       <th id="T_5864d_level0_col17" class="col_heading level0 col17" >Провозная плата.6</th>
#       <th id="T_5864d_level0_col18" class="col_heading level0 col18" >Объем перевозок(тн).6</th>
#       <th id="T_5864d_level0_col19" class="col_heading level0 col19" >Провозная плата.7</th>
#       <th id="T_5864d_level0_col20" class="col_heading level0 col20" >Объем перевозок(тн).7</th>
#       <th id="T_5864d_level0_col21" class="col_heading level0 col21" >Провозная плата.8</th>
#       <th id="T_5864d_level0_col22" class="col_heading level0 col22" >Объем перевозок(тн).8</th>
#       <th id="T_5864d_level0_col23" class="col_heading level0 col23" >Провозная плата.9</th>
#       <th id="T_5864d_level0_col24" class="col_heading level0 col24" >Объем перевозок(тн).9</th>
#       <th id="T_5864d_level0_col25" class="col_heading level0 col25" >Провозная плата.10</th>
#       <th id="T_5864d_level0_col26" class="col_heading level0 col26" >Объем перевозок(тн).10</th>
#       <th id="T_5864d_level0_col27" class="col_heading level0 col27" >Провозная плата.11</th>
#       <th id="T_5864d_level0_col28" class="col_heading level0 col28" >Объем перевозок(тн).11</th>
#       <th id="T_5864d_level0_col29" class="col_heading level0 col29" >Провозная плата.12</th>
#       <th id="T_5864d_level0_col30" class="col_heading level0 col30" >Объем перевозок(тн).12</th>
#       <th id="T_5864d_level0_col31" class="col_heading level0 col31" >Провозная плата.13</th>
#       <th id="T_5864d_level0_col32" class="col_heading level0 col32" >Объем перевозок(тн).13</th>
#       <th id="T_5864d_level0_col33" class="col_heading level0 col33" >Провозная плата.14</th>
#       <th id="T_5864d_level0_col34" class="col_heading level0 col34" >Объем перевозок(тн).14</th>
#       <th id="T_5864d_level0_col35" class="col_heading level0 col35" >Провозная плата.15</th>
#       <th id="T_5864d_level0_col36" class="col_heading level0 col36" >Объем перевозок(тн).15</th>
#       <th id="T_5864d_level0_col37" class="col_heading level0 col37" >Провозная плата.16</th>
#       <th id="T_5864d_level0_col38" class="col_heading level0 col38" >Объем перевозок(тн).16</th>
#       <th id="T_5864d_level0_col39" class="col_heading level0 col39" >Провозная плата.17</th>
#       <th id="T_5864d_level0_col40" class="col_heading level0 col40" >Объем перевозок(тн).17</th>
#       <th id="T_5864d_level0_col41" class="col_heading level0 col41" >Провозная плата.18</th>
#       <th id="T_5864d_level0_col42" class="col_heading level0 col42" >Объем перевозок(тн).18</th>
#       <th id="T_5864d_level0_col43" class="col_heading level0 col43" >Провозная плата.19</th>
#       <th id="T_5864d_level0_col44" class="col_heading level0 col44" >Объем перевозок(тн).19</th>
#       <th id="T_5864d_level0_col45" class="col_heading level0 col45" >Провозная плата.20</th>
#       <th id="T_5864d_level0_col46" class="col_heading level0 col46" >Объем перевозок(тн).20</th>
#       <th id="T_5864d_level0_col47" class="col_heading level0 col47" >Провозная плата.21</th>
#       <th id="T_5864d_level0_col48" class="col_heading level0 col48" >Объем перевозок(тн).21</th>
#       <th id="T_5864d_level0_col49" class="col_heading level0 col49" >Провозная плата.22</th>
#       <th id="T_5864d_level0_col50" class="col_heading level0 col50" >Объем перевозок(тн).22</th>
#       <th id="T_5864d_level0_col51" class="col_heading level0 col51" >Провозная плата.23</th>
#       <th id="T_5864d_level0_col52" class="col_heading level0 col52" >Объем перевозок(тн).23</th>
#       <th id="T_5864d_level0_col53" class="col_heading level0 col53" >Провозная плата.24</th>
#       <th id="T_5864d_level0_col54" class="col_heading level0 col54" >Объем перевозок(тн).24</th>
#       <th id="T_5864d_level0_col55" class="col_heading level0 col55" >Провозная плата.25</th>
#       <th id="T_5864d_level0_col56" class="col_heading level0 col56" >Объем перевозок(тн).25</th>
#       <th id="T_5864d_level0_col57" class="col_heading level0 col57" >Провозная плата.26</th>
#       <th id="T_5864d_level0_col58" class="col_heading level0 col58" >Объем перевозок(тн).26</th>
#       <th id="T_5864d_level0_col59" class="col_heading level0 col59" >Провозная плата.27</th>
#       <th id="T_5864d_level0_col60" class="col_heading level0 col60" >Объем перевозок(тн).27</th>
#       <th id="T_5864d_level0_col61" class="col_heading level0 col61" >Провозная плата.28</th>
#       <th id="T_5864d_level0_col62" class="col_heading level0 col62" >Объем перевозок(тн).28</th>
#       <th id="T_5864d_level0_col63" class="col_heading level0 col63" >Провозная плата.29</th>
#       <th id="T_5864d_level0_col64" class="col_heading level0 col64" >Объем перевозок(тн).29</th>
#       <th id="T_5864d_level0_col65" class="col_heading level0 col65" >Провозная плата.30</th>
#       <th id="T_5864d_level0_col66" class="col_heading level0 col66" >Объем перевозок(тн).30</th>
#       <th id="T_5864d_level0_col67" class="col_heading level0 col67" >Провозная плата.31</th>
#       <th id="T_5864d_level0_col68" class="col_heading level0 col68" >Объем перевозок(тн).31</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5864d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5864d_row0_col0" class="data row0 col0" >21220</td>
#       <td id="T_5864d_row0_col1" class="data row0 col1" >Рязанская область</td>
#       <td id="T_5864d_row0_col2" class="data row0 col2" >Оренбургская область</td>
#       <td id="T_5864d_row0_col3" class="data row0 col3" >39146</td>
#       <td id="T_5864d_row0_col4" class="data row0 col4" >МЕТИЗЫ</td>
#       <td id="T_5864d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_5864d_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_5864d_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_5864d_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_5864d_row0_col9" class="data row0 col9" >140356</td>
#       <td id="T_5864d_row0_col10" class="data row0 col10" >36</td>
#       <td id="T_5864d_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_5864d_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_5864d_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_5864d_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_5864d_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_5864d_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_5864d_row0_col17" class="data row0 col17"

# %% [raw]
# # Только 2 период
# input_file = r'Interests_Calls_Volumes\Объёмы перевозок.xls'
# output_file = r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx'
#
# data = pd.read_excel(input_file, header=1)
#
# # Убираем лишние пробелы в названиях колонок и переименовываем
# data.columns = data.columns.str.strip()
# data.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
#
# # Определяем текущую дату
# current_year = 2024
# current_month = 10
#
# # Последние 6 доступных месяцев
# available_months = []
#
# # Проходим по месяцам начиная с текущего и идем назад во времени
# for year in range(current_year, 2020, -1):  # Предположим, что данные начинаются с 2020 года
#     for month in range(12, 0, -1):
#         month_str = f'{year}/{month:02d}'
#         if month_str in data.columns and f'{month_str}.1' in data.columns:
#             available_months.append(month_str)
#             if len(available_months) == 6:
#                 break
#     if len(available_months) == 6:
#         break
#
#
# if len(available_months) < 6:
#     print("Недостаточно месяцев для анализа. Найденные месяцы:", available_months)
# else:
#     results = []
#
#     # Проходим по всем строкам данных
#     for _, row in data.iterrows():
#         id_value = row['ID']
#         for month in available_months:
#             # Проверяем, есть ли данные для данного месяца
#             if pd.notna(row[month]) and pd.notna(row[f'{month}.1']):
#                 results.append({
#                     'ID': id_value,
#                     'Провозная плата': row[month],
#                     'Объем перевозок(тн)': row[f'{month}.1']
#                 })
#
#     # Превращаем результаты в DataFrame
#     result_df = pd.DataFrame(results)
#
#     # Группировка по 'ID' и агрегирование сумм для итоговой таблицы
#     final_result = result_df.groupby('ID').agg(
#         Провозная_плата_сумма=('Провозная плата', 'sum'),
#         Объем_перевозок_сумма=('Объем перевозок(тн)', 'sum')
#     ).reset_index()
#
#
#     final_result = final_result.iloc[:-1]
#     final_result.to_excel(output_file, index=False)
#     print("Фильтрация завершена. Результат сохранен в:", output_file)
# print("Используются месяцы: ", available_months)

# %%
import pandas as pd

input_file = r'Interests_Calls_Volumes\Объёмы перевозок.xls'
output_file = r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx'

data = pd.read_excel(input_file, header=1)

# Убираем лишние пробелы в названиях колонок и переименовываем
data.columns = data.columns.str.strip()
data.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)

# Определяем текущую дату
current_year = 2024
current_month = 10  

# Последние 12 доступных месяцев
available_months = []

# Проходим по месяцам начиная с текущего и идем назад во времени
for year in range(current_year, 2019, -1):  # Предположим, что данные начинаются с 2020 года
    for month in range(12, 0, -1):
        month_str = f'{year}/{month:02d}'
        if month_str in data.columns and f'{month_str}.1' in data.columns:
            available_months.append(month_str)
            if len(available_months) == 12:
                break
    if len(available_months) == 12:
        break

if len(available_months) < 12:
    print("Недостаточно месяцев для анализа. Найденные месяцы:", available_months)
else:
    results = []

    # Определяем периоды
    period_1 = available_months[:6]  # Первые 6 месяцев
    period_2 = available_months[6:12] # Последние 6 месяцев

    # Проходим по всем строкам данных
    for _, row in data.iterrows():
        id_value = row['ID']
        
        # Собираем данные для первых 6 месяцев
        провозная_плата_1 = row[period_1].sum() if all(pd.notna(row[month]) for month in period_1) else None
        объем_перевозок_1 = row[[f'{month}.1' for month in period_1]].sum() if провозная_плата_1 is not None else None

        # Собираем данные для последних 6 месяцев
        провозная_плата_2 = row[period_2].sum() if all(pd.notna(row[month]) for month in period_2) else None
        объем_перевозок_2 = row[[f'{month}.1' for month in period_2]].sum() if провозная_плата_2 is not None else None

        results.append({
            'ID': id_value,
            'Провозная плата (период 1)': провозная_плата_1,
            'Объем перевозок(тн) (период 1)': объем_перевозок_1,
            'Провозная плата (период 2)': провозная_плата_2,
            'Объем перевозок(тн) (период 2)': объем_перевозок_2
        })

    # Превращаем результаты в DataFrame
    result_df = pd.DataFrame(results)

    # Убираем строки с отсутствующими данными
    result_df.dropna(subset=['Провозная плата (период 1)', 'Объем перевозок(тн) (период 1)', 
                             'Провозная плата (период 2)', 'Объем перевозок(тн) (период 2)'], inplace=True)

    result_df.to_excel(output_file, index=False)
    print("Фильтрация завершена. Результат сохранен в:", output_file)

print("Используются месяцы: ", available_months)
# Out:
# Фильтрация завершена. Результат сохранен в: Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx
# Используются месяцы:  ['2024/08', '2024/07', '2024/06', '2024/05', '2024/04', '2024/03', '2024/02', '2024/01', '2023/12', '2023/11', '2023/10', '2023/09']

# %%
# убирает непотребства 
file_path = r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx'
df = pd.read_excel(file_path, header=1)  # header=1 пропускает первую строку

df.columns = [
    'ID', 
    'Провозная плата (период 2)', 
    'Объем перевозок(тн) (период 2)', 
    'Провозная плата (период 1)', 
    'Объем перевозок(тн) (период 1)'
]

# Суммирование по уникальному ID
df_summary = df.groupby('ID').sum().reset_index()

# Сохранение результата в новый файл, если нужно
output_path = r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_periods.xlsx'
df_summary.to_excel(output_path, index=False)

# %%
data = pd.read_excel(r'Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_periods.xlsx')
data.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_49a44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49a44_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_49a44_level0_col1" class="col_heading level0 col1" >Провозная плата (период 2)</th>
#       <th id="T_49a44_level0_col2" class="col_heading level0 col2" >Объем перевозок(тн) (период 2)</th>
#       <th id="T_49a44_level0_col3" class="col_heading level0 col3" >Провозная плата (период 1)</th>
#       <th id="T_49a44_level0_col4" class="col_heading level0 col4" >Объем перевозок(тн) (период 1)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49a44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49a44_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_49a44_row0_col1" class="data row0 col1" >168141</td>
#       <td id="T_49a44_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_49a44_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_49a44_row0_col4" class="data row0 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_49a44_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49a44_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_49a44_row1_col1" class="data row1 col1" >18211112</td>
#       <td id="T_49a44_row1_col2" class="data row1 col2" >34923</td>
#       <td id="T_49a44_row1_col3" class="data row1 col3" >12754399</td>
#       <td id="T_49a44_row1_col4" class="data row1 col4" >31095</td>
#     </tr>
#     <tr>
#       <th id="T_49a44_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49a44_row2_col0" class="data row2 col0" >33</td>
#       <td id="T_49a44_row2_col1" class="data row2 col1" >105789052</td>
#       <td id="T_49a44_row2_col2" class="data row2 col2" >31213</td>
#       <td id="T_49a44_row2_col3" class="data row2 col3" >80731499</td>
#       <td id="T_49a44_row2_col4" class="data row2 col4" >28510</td>
#     </tr>
#     <tr>
#       <th id="T_49a44_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49a44_row3_col0" class="data row3 col0" >86</td>
#       <td id="T_49a44_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_49a44_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_49a44_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_49a44_row3_col4" class="data row3 col4" >0</td>
#     </tr>
#     <tr>
#       <th id="T_49a44_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49a44_row4_col0" class="data row4 col0" >115</td>
#       <td id="T_49a44_row4_col1" class="data row4 col1" >113617841</td>
#       <td id="T_49a44_row4_col2" class="data row4 col2" >41348</td>
#       <td id="T_49a44_row4_col3" class="data row4 col3" >79490420</td>
#       <td id="T_49a44_row4_col4" class="data row4 col4" >30340</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# #тип данных в ID
# df = pd.read_excel('Interests_Calls_Volumes_FILTERED\Объёмы_перевозок_filtered.xlsx')
# print(df['ID'].dtype)

# %% [markdown]
# ## Обращения.xls

# %%
import pandas as pd

# %%
у меня есть r'Sample_20_people\filtered_data.xlsx' в нём есть ID также есть Interests_Calls_Volumes\Обращения.xls

# %%
file_path = 'Interests_Calls_Volumes/Обращения.xls'
df = pd.read_excel(file_path)

topic_counts = df['Тема вопроса'].value_counts()

for topic, count in topic_counts.items():
    print(f"{topic}: {count}")
# Out:
# Справочный запрос: 1423
# Цифровые сервисы: 454
# Электронный обмен документами: 320
# Перевозка грузов и порожних вагонов: 213
# Оформление документов связанных с перевозкой грузов: 125
# Заключение договоров: 104
# Дополнительные услуги: 76
# Финансовые расчеты: 49
# Жалобы: 22
# Перевозка грузов в контейнерах: 21
# Благодарности: 9
# Перевозка грузов в рефрижераторных секциях ИВ-термосах вагонах-термосах: 7
# Перевозка сборной/мелкой партии грузов / разовая: 2

# %% [markdown]
# ## создание дополнительного параметра positiv_action

# %%
activity_file_path = 'Interests_Calls_Volumes/Обращения.xls'
activity_df = pd.read_excel(activity_file_path)


filtered_data_path = 'Sample_20_people/filtered_data.xlsx'
filtered_df = pd.read_excel(filtered_data_path)

topics_of_interest = [
    "Цифровые сервисы",
    "Электронный обмен документами",
    "Перевозка грузов и порожних вагонов",
    "Оформление документов связанных с перевозкой грузов",
    "Заключение договоров",
    "Финансовые расчеты",
    "Перевозка грузов в контейнерах",
    "Благодарности",
    "Перевозка грузов в рефрижераторных секциях ИВ-термосах вагонах-термосах",
    "Перевозка сборной/мелкой партии грузов / разовая"
]


filtered_activity_df = activity_df[activity_df['Тема вопроса'].isin(topics_of_interest)]
positive_action_counts = filtered_activity_df['ID'].value_counts()

filtered_df['positive_action'] = filtered_df['ID'].map(positive_action_counts).fillna(0)


output_path = 'Sample_20_people/filtered_data_with_positive_action.xlsx'
filtered_df.to_excel(output_path, index=False)

# %%
data = pd.read_excel(r'Sample_20_people/filtered_data_with_positive_action.xlsx')
data.head().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d3fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d3fd_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_8d3fd_level0_col1" class="col_heading level0 col1" >Находится в реестре МСП</th>
#       <th id="T_8d3fd_level0_col2" class="col_heading level0 col2" >Размер уставного капитала объявленный</th>
#       <th id="T_8d3fd_level0_col3" class="col_heading level0 col3" >Численность персонала по данным ФНС.Количество</th>
#       <th id="T_8d3fd_level0_col4" class="col_heading level0 col4" >Карточка клиента (внешний источник).Индекс платежной дисциплины Значение</th>
#       <th id="T_8d3fd_level0_col5" class="col_heading level0 col5" >Карточка клиента (внешний источник).Индекс финансового риска Значение</th>
#       <th id="T_8d3fd_level0_col6" class="col_heading level0 col6" >Провозная плата (период 1)</th>
#       <th id="T_8d3fd_level0_col7" class="col_heading level0 col7" >Провозная плата (период 2)</th>
#       <th id="T_8d3fd_level0_col8" class="col_heading level0 col8" >Объем перевозок(тн) (период 1)</th>
#       <th id="T_8d3fd_level0_col9" class="col_heading level0 col9" >Объем перевозок(тн) (период 2)</th>
#       <th id="T_8d3fd_level0_col10" class="col_heading level0 col10" >positive_action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d3fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d3fd_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_8d3fd_row0_col1" class="data row0 col1" >Нет</td>
#       <td id="T_8d3fd_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8d3fd_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_8d3fd_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8d3fd_row0_col5" class="data row0 col5" >27.000000</td>
#       <td id="T_8d3fd_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_8d3fd_row0_col7" class="data row0 col7" >168141</td>
#       <td id="T_8d3fd_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_8d3fd_row0_col9" class="data row0 col9" >50</td>
#       <td id="T_8d3fd_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8d3fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d3fd_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_8d3fd_row1_col1" class="data row1 col1" >Нет</td>
#       <td id="T_8d3fd_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_8d3fd_row1_col3" class="data row1 col3" >361.000000</td>
#       <td id="T_8d3fd_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_8d3fd_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_8d3fd_row1_col6" class="data row1 col6" >12754399</td>
#       <td id="T_8d3fd_row1_col7" class="data row1 col7" >18211112</td>
#       <td id="T_8d3fd_row1_col8" class="data row1 col8" >31095</td>
#       <td id="T_8d3fd_row1_col9" class="data row1 col9" >34923</td>
#       <td id="T_8d3fd_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d3fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d3fd_row2_col0" class="data row2 col0" >33</td>
#       <td id="T_8d3fd_row2_col1" class="data row2 col1" >Нет</td>
#       <td id="T_8d3fd_row2_col2" class="data row2 col2" >443485350.000000</td>
#       <td id="T_8d3fd_row2_col3" class="data row2 col3" >1987.000000</td>
#       <td id="T_8d3fd_row2_col4" class="data row2 col4" >84.000000</td>
#       <td id="T_8d3fd_row2_col5" class="data row2 col5" >21.000000</td>
#       <td id="T_8d3fd_row2_col6" class="data row2 col6" >80731499</td>
#       <td id="T_8d3fd_row2_col7" class="data row2 col7" >105789052</td>
#       <td id="T_8d3fd_row2_col8" class="data row2 col8" >28510</td>
#       <td id="T_8d3fd_row2_col9" class="data row2 col9" >31213</td>
#       <td id="T_8d3fd_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d3fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d3fd_row3_col0" class="data row3 col0" >86</td>
#       <td id="T_8d3fd_row3_col1" class="data row3 col1" >Нет</td>
#       <td id="T_8d3fd_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_8d3fd_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_8d3fd_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_8d3fd_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_8d3fd_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_8d3fd_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_8d3fd_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_8d3fd_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_8d3fd_row3_col10" class="data row3 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8d3fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d3fd_row4_col0" class="data row4 col0" >115</td>
#       <td id="T_8d3fd_row4_col1" class="data row4 col1" >Нет</td>
#       <td id="T_8d3fd_row4_col2" class="data row4 col2" >20773333.000000</td>
#       <td id="T_8d3fd_row4_col3" class="data row4 col3" >1211.000000</td>
#       <td id="T_8d3fd_row4_col4" class="data row4 col4" >96.000000</td>
#       <td id="T_8d3fd_row4_col5" class="data row4 col5" >16.000000</td>
#       <td id="T_8d3fd_row4_col6" class="data row4 col6" >79490420</td>
#       <td id="T_8d3fd_row4_col7" class="data row4 col7" >113617841</td>
#       <td id="T_8d3fd_row4_col8" class="data row4 col8" >30340</td>
#       <td id="T_8d3fd_row4_col9" class="data row4 col9" >41348</td>
#       <td id="T_8d3fd_row4_col10" class="data row4 col10" >2</td>
#     </tr>
#   </tbody>
# </table>
